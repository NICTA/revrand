# %% [markdown]
# # Distributed  Generalised Linear Models demo with Spark

# %%
# %matplotlib inline

import matplotlib.pyplot as pl
import numpy as np
import logging
from scipy.stats import poisson, bernoulli
from revrand import basis_functions, glm, likelihoods, transforms
from revrand.utils.datasets import gen_gausprocess_se

# Set up logging
logging.basicConfig(level=logging.INFO)
log = logging.getLogger(__name__)

# %% [markdown]
# Setup. Create dataset.

# %%
# Algorithmic properties
nbases = 100
lenscale = 1  # For all basis functions that take lengthscales
noise = 1
rate = 0.9
eta = 1e-5
passes = 400
batchsize = 100
reg = 1
postcomp = 5
use_sgd = True

N = 500
Ns = 250

# Dataset properties
lenscale_true = 0.7  # For the gpdraw dataset
noise_true = 0.1

# Likelihood
# like = 'Gaussian'
# like = 'Bernoulli'
like = 'Poisson'

# %%
lnoise = noise_true if like == 'Gaussian' else 0
Xtrain, ytrain, Xtest, ftest = \
    gen_gausprocess_se(N, Ns, lenscale=lenscale_true, noise=lnoise)

if like == 'Bernoulli':
    ytrain = bernoulli.rvs(transforms.logistic(20 * ytrain))
    ftest = transforms.logistic(20 * ftest)

elif like == 'Poisson':
    ytrain = poisson.rvs(transforms.softplus(5 * ytrain))
    ftest = transforms.softplus(5 * ftest)

# Make Bases and Likelihood
if like == 'Gaussian':
    llhood = likelihoods.Gaussian()
    lparams = [noise**2]
elif like == 'Bernoulli':
    llhood = likelihoods.Bernoulli()
    lparams = []
elif like == 'Poisson':
    llhood = likelihoods.Poisson(tranfcn='softplus')
    lparams = []
else:
    raise ValueError("Invalid likelihood, {}!".format(like))

basis = basis_functions.RandomRBF(nbases, Xtrain.shape[1])
bparams = [lenscale]

# %% [markdown]
# Create Spark RDD (Resilient Distributed Dataset):

# %%
train_data = np.hstack((ytrain[:, np.newaxis], Xtrain))
data = sc.parallelize(train_data)
N = data.count()
q = data.getNumPartitions()
print("Training data RDD: {} data points across {} partitions.".format(N,q))
# Out:
# Training data RDD: 500 data points across 6 partitions.

# %% [markdown]
# Run glm.learn using Spark

# %%
params = glm.learn(data, llhood, lparams, basis, bparams,
                   postcomp=postcomp, reg=reg, use_sgd=use_sgd, 
                   rate=rate, eta=eta, batchsize=batchsize, 
                   maxit=passes, spark=True)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-14-6ff15c9b763d> in <module>()
#       2                    postcomp=postcomp, reg=reg, use_sgd=use_sgd,
#       3                    rate=rate, eta=eta, batchsize=batchsize,
# ----> 4                    maxit=passes, spark=True)
#
# /usr/local/lib/python3.4/dist-packages/revrand/glm.py in learn(data, likelihood, lparams, basis, bparams, reg, postcomp, use_sgd, maxit, tol, batchsize, rate, eta, verbose, spark)
#     253         res = nsgd(L2, [m, C, reg, lparams, bparams], data, rate=rate, eta=eta,
#     254                    bounds=bounds, gtol=tol, passes=maxit, batchsize=batchsize,
# --> 255                    eval_obj=True)
#     256
#     257     m, C, reg, lparams, bparams = res.x
#
# /usr/local/lib/python3.4/dist-packages/revrand/optimize/base.py in new_sgd(fun, ndarrays, Data, bounds, eval_obj, **sgd_kwargs)
#     638
#     639         result = sgd(new_fun, array1d, Data=Data, bounds=fbounds,
# --> 640                      eval_obj=eval_obj, **sgd_kwargs)
#     641         result['x'] = tuple(unflatten(result['x'], shapes))
#     642         return result
#
# /usr/local/lib/python3.4/dist-packages/revrand/optimize/base.py in new_sgd(fun, x0, Data, bounds, eval_obj, **sgd_kwargs)
#     786         # Transform the final result
#     787         result = sgd(new_fun, logx(x0), Data, bounds=bounds, eval_obj=eval_obj,
# --> 788                      **sgd_kwargs)
#     789         result['x'] = expx(result['x'])
#     790         return result
#
# /usr/local/lib/python3.4/dist-packages/revrand/optimize/sgd_spark.py in sgd_spark(fun, x0, Data, args, bounds, batchsize, gtol, passes, eval_obj, rate, eta)
#      64     updater = AdaDelta(rate, eta)
#      65     return sgd_u_spark(fun, x0, Data, args, updater, bounds,
# ---> 66                        batchsize, gtol, passes, eval_obj)
#      67
#      68
#
# /usr/local/lib/python3.4/dist-packages/revrand/optimize/sgd_spark.py in sgd_u_spark(fun, x0, Data, args, updater, bounds, batchsize, gtol, passes, eval_obj)
#     129                 grad = Data.mapPartitions(fgrad).reduce(join1)
#     130             else:
# --> 131                 obj, grad = Data.mapPartitions(fgrad).reduce(join2)
#     132
#     133             grad /= q
#
# /opt/spark/python/pyspark/rdd.py in reduce(self, f)
#     795             yield reduce(f, iterator, initial)
#     796
# --> 797         vals = self.mapPartitions(func).collect()
#     798         if vals:
#     799             return reduce(f, vals)
#
# /opt/spark/python/pyspark/rdd.py in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /opt/spark/python/pyspark/rdd.py in _jrdd(self)
#    2377         command = (self.func, profiler, self._prev_jrdd_deserializer,
#    2378                    self._jrdd_deserializer)
# -> 2379         pickled_cmd, bvars, env, includes = _prepare_for_python_RDD(self.ctx, command, self)
#    2380         python_rdd = self.ctx._jvm.PythonRDD(self._prev_jrdd.rdd(),
#    2381                                              bytearray(pickled_cmd),
#
# /opt/spark/python/pyspark/rdd.py in _prepare_for_python_RDD(sc, command, obj)
#    2297     # the serialized command will be compressed by broadcast
#    2298     ser = CloudPickleSerializer()
# -> 2299     pickled_command = ser.dumps(command)
#    2300     if len(pickled_command) > (1 << 20):  # 1M
#    2301         # The broadcast will have same life cycle as created PythonRDD
#
# /opt/spark/python/pyspark/serializers.py in dumps(self, obj)
#     426
#     427     def dumps(self, obj):
# --> 428         return cloudpickle.dumps(obj, 2)
#     429
#     430
#
# /opt/spark/python/pyspark/cloudpickle.py in dumps(obj, protocol)
#     644
#     645     cp = CloudPickler(file,protocol)
# --> 646     cp.dump(obj)
#     647
#     648     return file.getvalue()
#
# /opt/spark/python/pyspark/cloudpickle.py in dump(self, obj)
#     105         self.inject_addons()
#     106         try:
# --> 107             return Pickler.dump(self, obj)
#     108         except RuntimeError as e:
#     109             if 'recursion' in e.args[0]:
#
# /usr/lib/python3.4/pickle.py in dump(self, obj)
#     410         if self.proto >= 4:
#     411             self.framer.start_framing()
# --> 412         self.save(obj)
#     413         self.write(STOP)
#     414         self.framer.end_framing()
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     742         write(MARK)
#     743         for element in obj:
# --> 744             save(element)
#     745
#     746         if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     796                 write(MARK)
#     797                 for x in tmp:
# --> 798                     save(x)
#     799                 write(APPENDS)
#     800             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     799                 write(APPENDS)
#     800             elif n:
# --> 801                 save(tmp[0])
#     802                 write(APPEND)
#     803             # else tmp is empty, and we're done
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     796                 write(MARK)
#     797                 for x in tmp:
# --> 798                     save(x)
#     799                 write(APPENDS)
#     800             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     796                 write(MARK)
#     797                 for x in tmp:
# --> 798                     save(x)
#     799                 write(APPENDS)
#     800             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     799                 write(APPENDS)
#     800             elif n:
# --> 801                 save(tmp[0])
#     802                 write(APPEND)
#     803             # else tmp is empty, and we're done
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     234         # create a skeleton function object and memoize it
#     235         save(_make_skel_func)
# --> 236         save((code, closure, base_globals))
#     237         write(pickle.REDUCE)
#     238         self.memoize(func)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_tuple(self, obj)
#     727         if n <= 3 and self.proto >= 2:
#     728             for element in obj:
# --> 729                 save(element)
#     730             # Subtle.  Same as in the big comment below.
#     731             if id(obj) in memo:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     796                 write(MARK)
#     797                 for x in tmp:
# --> 798                     save(x)
#     799                 write(APPENDS)
#     800             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function(self, obj, name)
#     197             klass = getattr(themodule, name, None)
#     198             if klass is None or klass is not obj:
# --> 199                 self.save_function_tuple(obj)
#     200                 return
#     201
#
# /opt/spark/python/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     239
#     240         # save the rest of the func data needed by _fill_function
# --> 241         save(f_globals)
#     242         save(defaults)
#     243         save(dct)
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_list(self, obj)
#     772
#     773         self.memoize(obj)
# --> 774         self._batch_appends(obj)
#     775
#     776     dispatch[list] = save_list
#
# /usr/lib/python3.4/pickle.py in _batch_appends(self, items)
#     799                 write(APPENDS)
#     800             elif n:
# --> 801                 save(tmp[0])
#     802                 write(APPEND)
#     803             # else tmp is empty, and we're done
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     522
#     523         # Save the reduce() output and finally memoize the object
# --> 524         self.save_reduce(obj=obj, *rv)
#     525
#     526     def persistent_id(self, obj):
#
# /opt/spark/python/pyspark/cloudpickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     540
#     541         if state is not None:
# --> 542             save(state)
#     543             write(pickle.BUILD)
#     544
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /usr/lib/python3.4/pickle.py in save_dict(self, obj)
#     812
#     813         self.memoize(obj)
# --> 814         self._batch_setitems(obj.items())
#     815
#     816     dispatch[dict] = save_dict
#
# /usr/lib/python3.4/pickle.py in _batch_setitems(self, items)
#     838                 for k, v in tmp:
#     839                     save(k)
# --> 840                     save(v)
#     841                 write(SETITEMS)
#     842             elif n:
#
# /usr/lib/python3.4/pickle.py in save(self, obj, save_persistent_id)
#     477         f = self.dispatch.get(t)
#     478         if f is not None:
# --> 479             f(self, obj) # Call unbound method with explicit self
#     480             return
#     481
#
# /opt/spark/python/pyspark/cloudpickle.py in save_file(self, obj)
#     569             raise pickle.PicklingError("Cannot pickle files that map to tty objects")
#     570         if 'r' not in obj.mode:
# --> 571             raise pickle.PicklingError("Cannot pickle files that are not opened for reading")
#     572         name = obj.name
#     573         try:
#
# PicklingError: Cannot pickle files that are not opened for reading

# %%
Ey, Vy, Eyn, Eyx = glm.predict_meanvar(Xtest, llhood, basis, *params)
plt1, plt1n, plt1x = glm.predict_cdf(0, Xtest, llhood, basis, *params)
y95n, y95x = glm.predict_interval(0.95, Xtest, llhood, basis, *params)

if like == 'Gaussian':
    Sy2 = 2 * np.sqrt(Vy + params[2][0])
else:
    Sy2 = 2 * np.sqrt(Vy)

# %% [markdown]
# Plot

# %%
Xpl_t = Xtrain.flatten()
Xpl_s = Xtest.flatten()

# Regressor
pl.plot(Xpl_s, Ey, 'b-', label='GLM mean.')
pl.fill_between(Xpl_s, Ey - Sy2, Ey + Sy2, facecolor='b', edgecolor='none',
                label=None, alpha=0.3)
# pl.fill_between(Xpl_s, Eyn, Eyx, facecolor='b', edgecolor='none', label=None,
#                 alpha=0.3)
pl.fill_between(Xpl_s, y95n, y95x, facecolor='none', edgecolor='b', label=None,
                linestyle='--')

pl.plot(Xpl_s, 1 - plt1, 'r-', label='NPV p(y >= 0).')
pl.fill_between(Xpl_s, 1 - plt1n, 1 - plt1x, facecolor='r', edgecolor='none',
                label=None, alpha=0.3)

# Training/Truth
pl.plot(Xpl_t, ytrain, 'k.', label='Training')
pl.plot(Xpl_s, ftest, 'k-', label='Truth')

pl.legend()
pl.grid(True)
pl.title('Regression demo')
pl.ylabel('y')
pl.xlabel('x')

m, C = params[0:2]
pl.figure()
K = m.shape[1]
cols = pl.cm.jet(np.linspace(0, 1, K))
for mk, Ck, c in zip(m.T, C.T, cols):
    pl.plot(range(len(mk)), mk, color=c)
    pl.fill_between(range(len(mk)), mk - 2 * np.sqrt(Ck), mk + 2 * np.sqrt(Ck),
                    alpha=0.1, edgecolor='none', facecolor=c, label=None)

pl.grid(True)
pl.title('Weight Posterior')
pl.ylabel('w')
pl.xlabel('basis index')

pl.show()
